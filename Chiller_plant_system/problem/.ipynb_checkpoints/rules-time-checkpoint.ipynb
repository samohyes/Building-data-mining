# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn import preprocessing
from sklearn.cluster import KMeans
from operator import itemgetter
import seaborn as sns
import Orange

# %%
"""
data = pd.read_csv('SAX_day_weekday_cp_sys.basket')
start = data.loc[0]
print(dict(start))
"""
with open('SAX_day_weekday_cp_sys.basket') as f:
    content = f.readlines()
content = [x.strip() for x in content]
content = content[1:]

# %%
ruleset = []
temp = []
for i in range(5422):
    if(float(content[i].split(',')[-1]) > float(content[i+1].split(',')[-1])):
        temp.append(content[i])
        ruleset.append(temp)
        temp = []
    else:
        temp.append(content[i])

# %%
fitdata = []
for j in range(len(ruleset)):
    datamid = []
    for i in range(len(ruleset[j])):
        datamid.append(ruleset[j][i].split(',')[:-1])
    fitdata.append(datamid)
print(fitdata)
# Out:
# [[['day_weekday_con_ret_tmp_high', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_low', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_low', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_low', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_low', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_high', 'day_weekday_stat1_out_tmp_mid', 'day_weekday_stat2_air_hum_high', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_mid'], ['day_weekday_con_ret_tmp_mid', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_low', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_high', 'day_weekday_stat1_out_tmp_mid', 'day_weekday_stat2_air_hum_high', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_mid'], ['day_weekday_con_ret_tmp_mid', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_low', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_high', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_mid', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_high', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_mid', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_low', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_mid', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_high', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_mid', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_mid'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_low', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_mid', 'day_weekday_tot_c ...

# %%
print(fitdata[2])
# Out:
# [['day_weekday_con_ret_tmp_high', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_low', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_low', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_low', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_low', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_high', 'day_weekday_stat1_out_tmp_mid', 'day_weekday_stat2_air_hum_high', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_mid'], ['day_weekday_con_ret_tmp_mid', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_low', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_high', 'day_weekday_stat1_out_tmp_mid', 'day_weekday_stat2_air_hum_high', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_mid'], ['day_weekday_con_ret_tmp_mid', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_low', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_high', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_high', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_mid', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_high', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_mid', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_mid', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_low', 'day_weekday_stat1_out_tmp_high', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_high'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_mid', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_high', 'day_weekday_tot_chi_eff_high', 'day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high', 'day_weekday_con_pump_kw_low', 'day_weekday_tow_sys_eff_high', 'day_weekday_tow_sys_kw_low', 'day_weekday_stat1_air_hum_mid', 'day_weekday_stat1_out_tmp_mid', 'day_weekday_stat2_air_hum_mid', 'day_weekday_stat2_wet_tmp_high', 'day_weekday_stat2_out_tmp_mid'], ['day_weekday_con_ret_tmp_low', 'day_weekday_con_sup_tmp_low', 'day_weekday_ch_sys_eff_high', 'day_weekday_ch_sys_kw_low', 'day_weekday_ch_pump_eff_high', 'day_weekday_ch_pump_kw_mid', 'day_weekday_tot_ch ...

# %%
import fpgrowth
import generaterules
itemset = fpgrowth.createInitSet(fitdata[2])
minSup = 0.1
itemnumber = 3
retTree, headerTable = fpgrowth.createTree(itemset, sum(itemset.values()), minSup=minSup)
freqItems = {}
fpgrowth.mineTree(inTree=retTree, headerTable=headerTable, dataSetLen=sum(itemset.values()), 
                  itemnumber = itemnumber, minSup = minSup, freqItemList = freqItems)
minConf = 0.7 
minLift = 0.9
ruleset = generaterules.generateRules(freqItems = freqItems, dataSetLen = sum(itemset.values()), 
                                      minConf = minConf, minLift = minLift)
print(ruleset)
# Out:
# [({frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_tow_sys_kw_low']): frozenset(['day_weekday_ch_sys_kw_low'])}, frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_tow_sys_kw_low']), frozenset(['day_weekday_ch_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_ch_sys_kw_low']): frozenset(['day_weekday_tow_sys_kw_low'])}, frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_ch_sys_kw_low']), frozenset(['day_weekday_tow_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_ch_sys_kw_low']): frozenset(['day_weekday_ch_pump_kw_low'])}, frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_ch_sys_kw_low']), frozenset(['day_weekday_ch_pump_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_ch_pump_kw_low']): frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_ch_sys_kw_low'])}, frozenset(['day_weekday_ch_pump_kw_low']), frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_ch_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tow_sys_kw_low']): frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_ch_sys_kw_low'])}, frozenset(['day_weekday_tow_sys_kw_low']), frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_ch_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_ch_sys_kw_low']): frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_tow_sys_kw_low'])}, frozenset(['day_weekday_ch_sys_kw_low']), frozenset(['day_weekday_ch_pump_kw_low', 'day_weekday_tow_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_tow_sys_kw_low']): frozenset(['day_weekday_con_pump_eff_high'])}, frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_tow_sys_kw_low']), frozenset(['day_weekday_con_pump_eff_high']), 1, 1, 1), ({frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high']): frozenset(['day_weekday_tow_sys_kw_low'])}, frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high']), frozenset(['day_weekday_tow_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_con_pump_eff_high']): frozenset(['day_weekday_tot_chi_kw_low'])}, frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_con_pump_eff_high']), frozenset(['day_weekday_tot_chi_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tot_chi_kw_low']): frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_con_pump_eff_high'])}, frozenset(['day_weekday_tot_chi_kw_low']), frozenset(['day_weekday_tow_sys_kw_low', 'day_weekday_con_pump_eff_high']), 1, 1, 1), ({frozenset(['day_weekday_tow_sys_kw_low']): frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high'])}, frozenset(['day_weekday_tow_sys_kw_low']), frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_con_pump_eff_high']), 1, 1, 1), ({frozenset(['day_weekday_con_pump_eff_high']): frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_tow_sys_kw_low'])}, frozenset(['day_weekday_con_pump_eff_high']), frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_tow_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_con_pump_kw_low']): frozenset(['day_weekday_ch_sys_kw_low'])}, frozenset(['day_weekday_con_pump_kw_low']), frozenset(['day_weekday_ch_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_ch_sys_kw_low']): frozenset(['day_weekday_con_pump_kw_low'])}, frozenset(['day_weekday_ch_sys_kw_low']), frozenset(['day_weekday_con_pump_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tot_chi_kw_low']): frozenset(['day_weekday_con_pump_eff_high'])}, frozenset(['day_weekday_tot_chi_kw_low']), frozenset(['day_weekday_con_pump_eff_high']), 1, 1, 1), ({frozenset(['day_weekday_con_pump_eff_high']): frozenset(['day_weekday_tot_chi_kw_low'])}, frozenset(['day_weekday_con_pump_eff_high']), frozenset(['day_weekday_tot_chi_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_ch_pump_kw_low']): frozenset(['day_weekday_ch_sys_kw_low'])}, frozenset(['day_weekday_tot_chi_kw_low', 'day_weekday_ch_pump_kw_low']), frozenset(['day_weekday_ch_sys_kw_low']), 1, 1, 1), ({frozenset(['day_weekday_tot_chi_kw_low ...

# %%
"""
myfile = open("temprule.basket","w")
for i in ruleset[0]:
    myfile.write(i)
    myfile.write("\n")
myfile.close()
data = Orange.data.Table('temprule.basket')
rules = Orange.associate.AssociationRulesSparseInducer(data, support=0.3)
print "%4s %4s %4s %4s" % ("Supp", "Conf", "Lift", "Rule")
for r in rules:
    print "%4.1f %4.1f %4.1f  %s" % (r.support, r.confidence, r.lift, r)
"""
# Out:
# '\nmyfile = open("temprule.basket","w")\nfor i in ruleset[0]:\n    myfile.write(i)\n    myfile.write("\n")\nmyfile.close()\ndata = Orange.data.Table(\'temprule.basket\')\nrules = Orange.associate.AssociationRulesSparseInducer(data, support=0.3)\nprint "%4s %4s %4s %4s" % ("Supp", "Conf", "Lift", "Rule")\nfor r in rules:\n    print "%4.1f %4.1f %4.1f  %s" % (r.support, r.confidence, r.lift, r)\n'
